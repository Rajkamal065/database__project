# %% [markdown]
# <a href="https://colab.research.google.com/github/Avinash143-ay/module-4/blob/main/test%20implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append('/content/drive/MyDrive/MODULE FOUR/database')

# %% [markdown]
# TASK1

# %%
from bplustree import BPlusTree

def test_bplus_tree():
    print("=== B+ Tree Testing Started ===")

    # Create tree with order 4
    tree = BPlusTree(order=4)

    # 1. Insert key-value pairs
    items = [(10, "a"), (20, "b"), (5, "c"), (6, "d"), (12, "e"),
             (30, "f"), (7, "g"), (17, "h")]
    print("\nInserting items:")
    for key, value in items:
        print(f"Inserting key {key} with value '{value}'")
        tree.insert(key, value)

    print("\nAll items after insertion:")
    print(tree.get_all())

    # 2. Search for existing and non-existing keys
    print("\nExact Search tests:")
    keys_to_search = [6, 17, 25]
    for key in keys_to_search:
        found, value = tree.search(key)
        if found:
            print(f"Key {key} found with value '{value}'")
        else:
            print(f"Key {key} not found.")

    # 3. Range Query
    print("\nRange Query (keys between 6 and 20):")
    result = tree.range_query(6, 20)
    print(result)

    # 4. Update a value
    print("\nUpdating key 12 to new value 'updated-e'")
    tree.update(12, "updated-e")
    print(tree.get_all())

    # 5. Delete keys and show tree after each
    keys_to_delete = [6, 7, 5, 10]
    print("\nDeleting keys one by one:")
    for key in keys_to_delete:
        print(f"Deleting key {key}")
        tree.delete(key)
        print("Current keys:", tree.get_all())



# Run the test
test_bplus_tree()
# Out:
# === B+ Tree Testing Started ===
#
# Inserting items:
# Inserting key 10 with value 'a'
# Inserting key 20 with value 'b'
# Inserting key 5 with value 'c'
# Inserting key 6 with value 'd'
# Inserting key 12 with value 'e'
# Inserting key 30 with value 'f'
# Inserting key 7 with value 'g'
# Inserting key 17 with value 'h'
#
# All items after insertion:
# [(5, 'c'), (6, 'd'), (7, 'g'), (12, 'e'), (17, 'h'), (30, 'f')]
#
# Exact Search tests:
# Key 6 found with value 'd'
# Key 17 found with value 'h'
# Key 25 not found.
#
# Range Query (keys between 6 and 20):
# [(6, 'd'), (7, 'g'), (12, 'e'), (17, 'h')]
#
# Updating key 12 to new value 'updated-e'
# [(5, 'c'), (6, 'd'), (7, 'g'), (12, 'updated-e'), (17, 'h'), (30, 'f')]
#
# Deleting keys one by one:
# Deleting key 6
# Current keys: [(5, 'c'), (7, 'g'), (12, 'updated-e'), (17, 'h'), (30, 'f')]
# Deleting key 7
# Current keys: [(5, 'c'), (10, 'a'), (12, 'updated-e'), (17, 'h'), (30, 'f')]
# Deleting key 5
# ...

# %% [markdown]
# TASK 2 is code it self

# %% [markdown]
# for 100 data set

# %%
import matplotlib.pyplot as plt
import numpy as np

operations = ['Insert', 'Search', 'Delete', 'Range Query']
bplustree_times = [4.72e-6, 2.96e-6, 4.83e-6, 5.27e-7]
bruteforce_times = [1.40e-6, 5.87e-6, 8.45e-7, 6.19e-7]

bplustree_memory = [0.344, 0.118, 0.135, 0.117]
bruteforce_memory = [0.110, 0.048, 0.119, 0.273]

x = np.arange(len(operations))
width = 0.35

# Time Comparison
fig, ax = plt.subplots(figsize=(10,6))
rects1 = ax.bar(x - width/2, bplustree_times, width, label='BPlusTree')
rects2 = ax.bar(x + width/2, bruteforce_times, width, label='BruteForceDB')

ax.set_ylabel('Average Time (seconds)')
ax.set_title('Performance Benchmark: Time Comparison')
ax.set_xticks(x)
ax.set_xticklabels(operations)
ax.legend()
plt.grid()
plt.show()

# Memory Comparison
fig, ax = plt.subplots(figsize=(10,6))
rects1 = ax.bar(x - width/2, bplustree_memory, width, label='BPlusTree')
rects2 = ax.bar(x + width/2, bruteforce_memory, width, label='BruteForceDB')

ax.set_ylabel('Average Memory (KB)')
ax.set_title('Performance Benchmark: Memory Comparison')
ax.set_xticks(x)
ax.set_xticklabels(operations)
ax.legend()
plt.grid()
plt.show()

# %% [markdown]
# 10,000 data set

# %%
import matplotlib.pyplot as plt
import numpy as np

# Operations
operations = ['Insert', 'Search', 'Delete', 'Range Query']
x = np.arange(len(operations))
width = 0.35

# Updated values
bplustree_times = [
    3.0034602619707585e-06,
    1.9434004789218308e-06,
    3.3169991569593547e-06,
    4.730800399556756e-07
]
bruteforce_times = [
    5.353900487534702e-07,
    0.0003146972703747451,
    3.318150022532791e-05,
    3.4207022981718184e-07
]

bplustree_memory = [
    0.3134068359375,
    0.1171875,
    0.13669375,
    0.1171875
]
bruteforce_memory = [
    0.1043837890625,
    0.046875,
    0.11719375,
    0.046875
]

# --------- Time Comparison ---------
fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, bplustree_times, width, label='BPlusTree', color='#4C72B0')
rects2 = ax.bar(x + width/2, bruteforce_times, width, label='BruteForceDB', color='#55A868')

ax.set_ylabel('Average Time (seconds)', fontsize=12)
ax.set_title('Performance Benchmark: Time Comparison', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(operations, fontsize=11)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Annotate Bars
for rect in rects1 + rects2:
    height = rect.get_height()
    ax.annotate(f'{height:.2e}',
                xy=(rect.get_x() + rect.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# --------- Memory Comparison ---------
fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, bplustree_memory, width, label='BPlusTree', color='#C44E52')
rects2 = ax.bar(x + width/2, bruteforce_memory, width, label='BruteForceDB', color='#8172B2')

ax.set_ylabel('Average Memory (KB)', fontsize=12)
ax.set_title('Performance Benchmark: Memory Comparison', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(operations, fontsize=11)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Annotate Bars
for rect in rects1 + rects2:
    height = rect.get_height()
    ax.annotate(f'{height:.3f}',
                xy=(rect.get_x() + rect.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# 1000 data set

# %%
import matplotlib.pyplot as plt
import numpy as np

# Operations
operations = ['Insert', 'Search', 'Delete', 'Range Query']
x = np.arange(len(operations))
width = 0.35

# Updated values (latest you sent)
bplustree_times = [
    2.315701451152563e-06,
    1.4781011268496513e-06,
    2.3303012130782006e-06,
    5.382999079301954e-07
]
bruteforce_times = [
    5.200001178309321e-07,
    3.243430028669536e-05,
    3.1436014687642453e-06,
    3.041008021682501e-07
]

bplustree_memory = [
    0.31341796875,
    0.1171875,
    0.1365625,
    0.1171875
]
bruteforce_memory = [
    0.103408203125,
    0.046875,
    0.11725,
    0.046875
]

# --------- Time Comparison ---------
fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, bplustree_times, width, label='BPlusTree', color='#4C72B0')
rects2 = ax.bar(x + width/2, bruteforce_times, width, label='BruteForceDB', color='#55A868')

ax.set_ylabel('Average Time (seconds)', fontsize=12)
ax.set_title('Performance Benchmark: Time Comparison', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(operations, fontsize=11)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Annotate Bars
for rect in rects1 + rects2:
    height = rect.get_height()
    ax.annotate(f'{height:.2e}',
                xy=(rect.get_x() + rect.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# --------- Memory Comparison ---------
fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, bplustree_memory, width, label='BPlusTree', color='#C44E52')
rects2 = ax.bar(x + width/2, bruteforce_memory, width, label='BruteForceDB', color='#8172B2')

ax.set_ylabel('Average Memory (KB)', fontsize=12)
ax.set_title('Performance Benchmark: Memory Comparison', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(operations, fontsize=11)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Annotate Bars
for rect in rects1 + rects2:
    height = rect.get_height()
    ax.annotate(f'{height:.3f}',
                xy=(rect.get_x() + rect.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# TASK 3 (it get png i will paste in report)

# %%
# Example usage
from bplustree import BPlusTree
tree = BPlusTree(order=3)
tree.insert(10, 'value10')
tree.insert(20, 'value20')
tree.insert(30, 'value30')
tree.insert(40, 'value40')
tree.insert(50, 'value50')
tree.insert(60, 'value60')
tree.insert(70, 'value70')
tree.insert(80, 'value80')
tree.insert(90, 'value90')
tree.insert(100, 'value100')
tree.insert(200, 'value200')
tree.insert(300, 'value300')
tree.visualize_tree("bplustree")
# Out:
# Tree visualization saved as bplustree.png

# %% [markdown]
# TASK 4

# %%
import random
import time
import matplotlib.pyplot as plt
from bplustree import BPlusTree
from bruteforce import BruteForceIndex

# Setup for experiment
sizes = list(range(1000, 10001, 1000))  # Sizes from 1000 to 10000
insert_times_bplus = []
insert_times_brute = []
search_times_bplus = []
search_times_brute = []
range_times_bplus = []
range_times_brute = []
delete_times_bplus = []
delete_times_brute = []

for size in sizes:
    print(f"Testing size: {size}")
    keys = random.sample(range(size * 10), size)  # random unique keys
    search_keys = random.sample(keys, min(100, size))  # pick 100 random keys to search
    delete_keys = random.sample(keys, min(100, size))  # pick 100 random keys to delete
    range_queries = [(random.randint(0, size * 5), random.randint(size * 5, size * 10)) for _ in range(10)]

    # Initialize Data Structures
    bplus = BPlusTree(order=6)
    brute = BruteForceIndex()

    # Insertion Timing
    start = time.time()
    for key in keys:
        bplus.insert(key, str(key))
    insert_times_bplus.append(time.time() - start)

    start = time.time()
    for key in keys:
        brute.insert(key, str(key))
    insert_times_brute.append(time.time() - start)

    # Search Timing
    start = time.time()
    for key in search_keys:
        bplus.search(key)
    search_times_bplus.append(time.time() - start)

    start = time.time()
    for key in search_keys:
        brute.search(key)
    search_times_brute.append(time.time() - start)

    # Range Query Timing
    start = time.time()
    for start_key, end_key in range_queries:
        bplus.range_query(start_key, end_key)
    range_times_bplus.append(time.time() - start)

    start = time.time()
    for start_key, end_key in range_queries:
        brute_range = [item for item in brute.get_all() if start_key <= item[0] <= end_key]
    range_times_brute.append(time.time() - start)

    # Deletion Timing
    start = time.time()
    for key in delete_keys:
        if bplus.search(key) is not None:
          bplus.delete(key)
    delete_times_bplus.append(time.time() - start)

    start = time.time()
    for key in delete_keys:
        if brute.search(key) is not None:
          brute.delete(key)
    delete_times_brute.append(time.time() - start)

# Plotting Results
plt.figure(figsize=(16, 12))

# Insertion Times
plt.subplot(2, 2, 1)
plt.plot(sizes, insert_times_bplus, label="B+ Tree Insert", marker='o')
plt.plot(sizes, insert_times_brute, label="Brute Force Insert", marker='x')
plt.xlabel("Number of Elements")
plt.ylabel("Time (seconds)")
plt.title("Insertion Time Comparison")
plt.legend()

# Search Times
plt.subplot(2, 2, 2)
plt.plot(sizes, search_times_bplus, label="B+ Tree Search", marker='o')
plt.plot(sizes, search_times_brute, label="Brute Force Search", marker='x')
plt.xlabel("Number of Elements")
plt.ylabel("Time (seconds)")
plt.title("Search Time Comparison")
plt.legend()

# Range Query Times
plt.subplot(2, 2, 3)
plt.plot(sizes, range_times_bplus, label="B+ Tree Range Query", marker='o')
plt.plot(sizes, range_times_brute, label="Brute Force Range Query", marker='x')
plt.xlabel("Number of Elements")
plt.ylabel("Time (seconds)")
plt.title("Range Query Time Comparison")
plt.legend()

# Deletion Times
plt.subplot(2, 2, 4)
plt.plot(sizes, delete_times_bplus, label="B+ Tree Delete", marker='o')
plt.plot(sizes, delete_times_brute, label="Brute Force Delete", marker='x')
plt.xlabel("Number of Elements")
plt.ylabel("Time (seconds)")
plt.title("Deletion Time Comparison")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Testing size: 1000
# Testing size: 2000
# Testing size: 3000
# Testing size: 4000
# Testing size: 5000
# Testing size: 6000
# Testing size: 7000
# Testing size: 8000
# Testing size: 9000
# Testing size: 10000

# %% [markdown]
# above task if we get out of range or index run the same 5 to 6 times we will get the graphs

# %%
from db_manager import Database
# Out:
# Table: students
# --------------------------------------------------
# | id              | name            | age             | grade           |
# -------------------------------------------------------------------------
# | 1               | Alice           | 20              | A               |
# | 2               | Bob             | 22              | B               |
#
# Showing 2 of 2 records

# %%
db = Database('school_db')

# %%
db.delete_table('professordata')
# Out:
# False

# %%
 professordata= db.create_table(
    name='professordata',
    columns={'professor': str, 'prof_id': int},
    primary_key='prof_id'
)

# %%
professordata.insert({'professor': 'Dr. Smith', 'prof_id': 101})
# Out:
# True

# %%
professordata.show()
# Out:
# Table: professordata
# --------------------------------------------------
# | professor       | prof_id         |
# -------------------------------------
# | Dr. Smith       | 101             |
#
# Showing 1 of 1 records

# %%
tables_name = db.list_tables()
tables_name
# Out:
# ['professordata']

# %%
db.delete_table('students')
# Out:
# False

# %%
students = db.create_table(
    name='students',
    columns={'id': int, 'name': str, 'age': int,'grade':str},  # No 'grade'
    primary_key='id'
)

# %%
students.insert({'id': 1, 'name': 'Alice', 'age': 20, 'grade': 'A'})
students.insert({'id': 2, 'name': 'Bob', 'age': 22, 'grade': 'B'})
students.show()
# Out:
# Table: students
# --------------------------------------------------
# | id              | name            | age             | grade           |
# -------------------------------------------------------------------------
# | 1               | Alice           | 20              | A               |
# | 2               | Bob             | 22              | B               |
#
# Showing 2 of 2 records

# %%
tables_name = db.list_tables()
tables_name
# Out:
# ['professordata', 'students']

# %%
table_stu = db.get_table('students')  # use the table name as a string

table_stu.show()
# Out:
# Table: students
# --------------------------------------------------
# | id              | name            | age             | grade           |
# -------------------------------------------------------------------------
# | 1               | Alice           | 20              | A               |
# | 2               | Bob             | 22              | B               |
#
# Showing 2 of 2 records

# %%
students.update(2, {'grade': 'A+'})  # Assuming update(pk_value, updated_fields)

print("\nAfter Updating Bob's grade:")
students.show()
# Out:
# After Updating Bob's grade:
#
# Table: students
# --------------------------------------------------
# | id              | name            | age             | grade           |
# -------------------------------------------------------------------------
# | 1               | Alice           | 20              | A               |
# | 2               | Bob             | 22              | A+              |
#
# Showing 2 of 2 records

# %%
# --- Delete Alice from the students table ---
students.delete(1)  # Assuming delete(pk_value)

print("\nAfter Deleting Alice:")
students.show()
# Out:
# After Deleting Alice:
#
# Table: students
# --------------------------------------------------
# | id              | name            | age             | grade           |
# -------------------------------------------------------------------------
# | 2               | Bob             | 22              | A+              |
#
# Showing 1 of 1 records

# %%
print("\nTables in database:", db.list_tables())
# Out:
# Tables in database: ['professordata', 'students']

# %%
professors_table = db.get_table('professordata')
print("\nProfessor Table Content:")
professors_table.show()
# Out:
# Professor Table Content:
#
# Table: professordata
# --------------------------------------------------
# | professor       | prof_id         |
# -------------------------------------
# | Dr. Smith       | 101             |
#
# Showing 1 of 1 records

# %%
students.insert({'id': 1, 'name': 'Alice', 'age': 20, 'grade': 'A'})
students.insert({'id': 4, 'name': 'Avi', 'age': 20, 'grade': 'C'})
students.insert({'id': 3, 'name': 'Bob', 'age': 22, 'grade': 'B'})
# Out:
# True

# %%
# Sum of ages
print("Sum of ages:", students.aggregate('age', 'sum'))

# Average age
print("Average age:", students.aggregate('age', 'avg'))

# Youngest student age
print("Minimum age:", students.aggregate('age', 'min'))

# Oldest student age
print("Maximum age:", students.aggregate('age', 'max'))

# Total number of students
print("Total students:", students.aggregate('id', 'count'))
# Out:
# Sum of ages: 84
# Average age: 21.0
# Minimum age: 20
# Maximum age: 22
# Total students: 4

# %%
db.persist()
print("\nDatabase persisted successfully.")
# Out:
# Database persisted successfully.

# %% [markdown]
# task 3 (Tree visualization saved as bplustree.png)

# %% [markdown]
# ![bplustree.png](data:image/png;base64,...)
